# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # K Nearest Neighbors Project
#
# Welcome to the KNN Project! This will be a simple project very similar to the lecture, except you'll be given another data set. Go ahead and just follow the directions below.
# ## Import Libraries
# **Import pandas,seaborn, and the usual libraries.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data
# ** Read the 'KNN_Project_Data csv file into a dataframe **

# %%
df = pd.read_csv("KNN_Project_Data", index_col = 0)

# %% [markdown]
# **Check the head of the dataframe.**

# %%
df.head()
# Out:
#                     GWYH         TRAT        TLLZ         IGGA         HYKR  \
# XVPM
# 1636.670614   817.988525  2565.995189  358.347163   550.417491  1618.870897
# 1013.402760   577.587332  2644.141273  280.428203  1161.873391  2084.107872
# 1300.035501   820.518697  2025.854469  525.562292   922.206261  2552.355407
# 1059.347542  1066.866418   612.000041  480.827789   419.467495   685.666983
# 1018.340526  1313.679056   950.622661  724.742174   843.065903  1370.554164
#
#                     EDFS        GUUB         MGJM         JHZC  TARGET CLASS
# XVPM
# 1636.670614  2147.641254  330.727893  1494.878631   845.136088             0
# 1013.402760   853.404981  447.157619  1193.032521   861.081809             1
# 1300.035501   818.676686  845.491492  1968.367513  1647.186291             1
# 1059.347542   852.867810  341.664784  1154.391368  1450.935357             0
# 1018.340526   905.469453  658.118202   539.459350  1899.850792             0

# %% [markdown]
# # EDA
#
# Since this data is artificial, we'll just do a large pairplot with seaborn.
#
# **Use seaborn on the dataframe to create a pairplot with the hue indicated by the TARGET CLASS column.**

# %%
sns.pairplot(df, hue = "TARGET CLASS", diag_kind = "hist" )

# %% [markdown]
# # Standardize the Variables
#
# Time to standardize the variables.
#
# ** Import StandardScaler from Scikit learn.**

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ** Create a StandardScaler() object called scaler.**

# %%
scaler = StandardScaler()

# %% [markdown]
# ** Fit scaler to the features.**

# %%
scaler.fit(df.drop("TARGET CLASS", axis = 1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# **Use the .transform() method to transform the features to a scaled version.**

# %%
scaled_features = scaler.transform(df.drop("TARGET CLASS", axis = 1))

# %% [markdown]
# **Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.**

# %%
features_df = pd.DataFrame(scaled_features, columns = df.columns[:-1])

# %%
features_df.head()
# Out:
#        GWYH      TRAT      TLLZ      IGGA      HYKR      EDFS      GUUB  \
# 0 -0.443435  1.619808 -0.958255 -1.128481  0.138336  0.980493 -0.932794
# 1 -1.056574  1.741918 -1.504220  0.640009  1.081552 -1.182663 -0.461864
# 2 -0.436981  0.775793  0.213394 -0.053171  2.030872 -1.240707  1.149298
# 3  0.191324 -1.433473 -0.100053 -1.507223 -1.753632 -1.183561 -0.888557
# 4  0.820815 -0.904346  1.609015 -0.282065 -0.365099 -1.095644  0.391419
#
#        MGJM      JHZC
# 0  1.008313 -1.069627
# 1  0.258321 -1.041546
# 2  2.184784  0.342811
# 3  0.162310 -0.002793
# 4 -1.365603  0.787762

# %% [markdown]
# # Train Test Split
#
# **Use train_test_split to split your data into a training set and a testing set.**

# %%
from sklearn.model_selection import train_test_split

# %%
X = features_df
y = df["TARGET CLASS"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Using KNN
#
# **Import KNeighborsClassifier from scikit learn.**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Create a KNN model instance with n_neighbors=1**

# %%
knn1 = KNeighborsClassifier(n_neighbors = 1)

# %% [markdown]
# **Fit this KNN model to the training data.**

# %%
knn1.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %% [markdown]
# # Predictions and Evaluations
# Let's evaluate our KNN model!

# %% [markdown]
# **Use the predict method to predict values using your KNN model and X_test.**

# %%
knn1_predicted = knn1.predict(X_test)

# %% [markdown]
# ** Create a confusion matrix and classification report.**

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, knn1_predicted))
# Out:
# [[118  45]
#  [ 44 123]]

# %%
print(classification_report(y_test, knn1_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73       163
#            1       0.73      0.74      0.73       167
#
#     accuracy                           0.73       330
#    macro avg       0.73      0.73      0.73       330
# weighted avg       0.73      0.73      0.73       330

# %% [markdown]
# # Choosing a K Value
# Let's go ahead and use the elbow method to pick a good K Value!
#
# ** Create a for loop that trains various KNN models with different k values, then keep track of the error_rate for each of these models with a list. Refer to the lecture if you are confused on this step.**

# %%
#Standard way
error_rates = []

for i in range(1,40):
    knni = KNeighborsClassifier(n_neighbors = i)
    knni.fit(X_train, y_train)
    knni_predicted = knni.predict(X_test)
    error_rate = np.mean(knni_predicted != y_test)
    error_rates.append(error_rate)  

#One liner, probably not worth lack of readability
error_rates2 = [np.mean(KNeighborsClassifier(n_neighbors = i).fit(X_train, y_train).predict(X_test) != y_test) for i in range(1,40)]

# %% [markdown]
# **Now create the following plot using the information from your for loop.**

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rates,color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# ## Retrain with new K Value
#
# **Retrain your model with the best K value (up to you to decide what you want) and re-do the classification report and the confusion matrix.**

# %%
"""
Going to choose K = 18 despite lower error rates in the k = 30-40 range. Error rate is a little unpredictable in this range
and not very consistent. In the 10-20 range the error rate is much more steady with a local minimum of around 0.17 or 17%.
"""
knn18 = KNeighborsClassifier(n_neighbors = 18)
knn18.fit(X_train, y_train)
knn18_predicted = knn18.predict(X_test)
print(confusion_matrix(y_test, knn18_predicted))
print(classification_report(y_test, knn18_predicted))
# Out:
# [[143  20]
#  [ 37 130]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       163
#            1       0.87      0.78      0.82       167
#
#     accuracy                           0.83       330
#    macro avg       0.83      0.83      0.83       330
# weighted avg       0.83      0.83      0.83       330

# %% [markdown]
# # Great Job!
